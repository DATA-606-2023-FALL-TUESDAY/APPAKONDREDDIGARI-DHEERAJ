# %% [markdown]
# # Capstone Project

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading file and stroing it in df
data ="C:\\Users\\dheeraj kumar reddy\\Downloads\\Motor_Vehicle_Collisions_-_Vehicles.csv"
df = pd.read_csv(data)

# %%
# checking head of dataframe
df.head()
# Out:
#    UNIQUE_ID  COLLISION_ID  CRASH_DATE CRASH_TIME
# 0   10385780        100201  09/07/2012       9:03  \
# 1   19140702       4213082  09/23/2019       8:15
# 2   14887647       3307608  10/02/2015      17:18
# 3   14889754       3308693  10/04/2015      20:34
# 4   14400270        297666  04/25/2013      21:15
#
#                              VEHICLE_ID STATE_REGISTRATION
# 0                                     1                 NY  \
# 1  0553ab4d-9500-4cba-8d98-f4d7f89d5856                 NY
# 2                                     2                 NY
# 3                                     1                 NY
# 4                                     1                 NY
#
#                           VEHICLE_TYPE   VEHICLE_MAKE VEHICLE_MODEL
# 0                    PASSENGER VEHICLE            NaN           NaN  \
# 1  Station Wagon/Sport Utility Vehicle  TOYT -CAR/SUV           NaN
# 2                                 TAXI            NaN           NaN
# ...

# %%
# describing df
df.describe()
# Out:
#           UNIQUE_ID  COLLISION_ID  VEHICLE_YEAR
# count  3.704406e+06  3.704406e+06  1.907435e+06
# mean   1.606087e+07  2.996659e+06  2.014806e+03
# std    3.244903e+06  1.495340e+06  1.551508e+02
# min    1.117110e+05  2.200000e+01  1.000000e+03
# 25%    1.421516e+07  3.017853e+06  2.008000e+03
# 50%    1.730606e+07  3.567068e+06  2.013000e+03
# 75%    1.873920e+07  4.028145e+06  2.016000e+03
# max    2.012172e+07  4.484197e+06  2.006300e+04

# %%
# checking columns of df
df.columns
# Out:
# Index(['UNIQUE_ID', 'COLLISION_ID', 'CRASH_DATE', 'CRASH_TIME', 'VEHICLE_ID',
#        'STATE_REGISTRATION', 'VEHICLE_TYPE', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'VEHICLE_YEAR', 'TRAVEL_DIRECTION', 'VEHICLE_OCCUPANTS', 'DRIVER_SEX',
#        'DRIVER_LICENSE_STATUS', 'DRIVER_LICENSE_JURISDICTION', 'PRE_CRASH',
#        'POINT_OF_IMPACT', 'VEHICLE_DAMAGE', 'VEHICLE_DAMAGE_1',
#        'VEHICLE_DAMAGE_2', 'VEHICLE_DAMAGE_3', 'PUBLIC_PROPERTY_DAMAGE',
#        'PUBLIC_PROPERTY_DAMAGE_TYPE', 'CONTRIBUTING_FACTOR_1',
#        'CONTRIBUTING_FACTOR_2'],
#       dtype='object')

# %%
# checking info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3704406 entries, 0 to 3704405
# Data columns (total 25 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   UNIQUE_ID                    int64
#  1   COLLISION_ID                 int64
#  2   CRASH_DATE                   object
#  3   CRASH_TIME                   object
#  4   VEHICLE_ID                   object
#  5   STATE_REGISTRATION           object
#  6   VEHICLE_TYPE                 object
#  7   VEHICLE_MAKE                 object
#  8   VEHICLE_MODEL                object
#  9   VEHICLE_YEAR                 float64
#  10  TRAVEL_DIRECTION             object
#  11  VEHICLE_OCCUPANTS            object
#  12  DRIVER_SEX                   object
#  13  DRIVER_LICENSE_STATUS        object
#  14  DRIVER_LICENSE_JURISDICTION  object
#  15  PRE_CRASH                    object
#  16  POINT_OF_IMPACT              object
#  17  VEHICLE_DAMAGE               object
# ...

# %%
# checking shape of df
df.shape
# Out:
# (3704406, 25)

# %%
# checking unique values of each column
df.nunique()
# Out:
# UNIQUE_ID                      3704406
# COLLISION_ID                   1845435
# CRASH_DATE                        3444
# CRASH_TIME                        1440
# VEHICLE_ID                     2175578
# STATE_REGISTRATION                  82
# VEHICLE_TYPE                      2141
# VEHICLE_MAKE                     10266
# VEHICLE_MODEL                     2429
# VEHICLE_YEAR                       299
# TRAVEL_DIRECTION                    15
# VEHICLE_OCCUPANTS                  184
# DRIVER_SEX                           3
# DRIVER_LICENSE_STATUS                3
# DRIVER_LICENSE_JURISDICTION         70
# PRE_CRASH                           19
# POINT_OF_IMPACT                     19
# VEHICLE_DAMAGE                      19
# VEHICLE_DAMAGE_1                    19
# VEHICLE_DAMAGE_2                    19
# VEHICLE_DAMAGE_3                    19
# PUBLIC_PROPERTY_DAMAGE               3
# PUBLIC_PROPERTY_DAMAGE_TYPE      14595
# CONTRIBUTING_FACTOR_1               61
# ...

# %%
# checking null values and priting them in bar chart
import matplotlib.pyplot as plt
df.isnull().sum().sort_values().plot(kind='bar', figsize=(15,5))
plt.title('Number of NaN values')
plt.xlabel('Columns')
plt.ylabel('Sum')
plt.show()

# %%
# checking value counts of TRAVEL_DIRECTION
df.TRAVEL_DIRECTION.value_counts()
# Out:
# TRAVEL_DIRECTION
# West         477593
# East         473030
# North        469862
# South        467518
# Unknown       70510
# Northeast     29068
# Southeast     27680
# Southwest     27106
# Northwest     25880
# -              1003
# S               206
# N               177
# W               175
# E               159
# U                28
# Name: count, dtype: int64

# %%
# checking value counts of CONTRIBUTING_FACTOR_1
df.CONTRIBUTING_FACTOR_1.value_counts()
# Out:
# CONTRIBUTING_FACTOR_1
# Unspecified                       2131906
# Driver Inattention/Distraction     444452
# Failure to Yield Right-of-Way      123777
# Following Too Closely              114654
# Other Vehicular                     90629
#                                    ...
# Shoulders Defective/Improper           95
# Windshield Inadequate                  80
# Texting                                45
# Listening/Using Headphones             29
# 1                                      16
# Name: count, Length: 61, dtype: int64

# %%
# checking value counts of CONTRIBUTING_FACTOR_2
df.CONTRIBUTING_FACTOR_2.value_counts()
# Out:
# CONTRIBUTING_FACTOR_2
# Unspecified                                              1628200
# Driver Inattention/Distraction                            110322
# Following Too Closely                                      48717
# Failure to Yield Right-of-Way                              33267
# Passing or Lane Usage Improper                             25839
# Driver Inexperience                                        24093
# Unsafe Lane Changing                                       23820
# Passing Too Closely                                        21500
# Other Vehicular                                            21166
# Unsafe Speed                                               18982
# Turning Improperly                                         15105
# Traffic Control Disregarded                                12817
# Backing Unsafely                                           11067
# Pavement Slippery                                           8066
# ...

# %%
# checking value counts of point of impact
df.POINT_OF_IMPACT.value_counts()
# Out:
# POINT_OF_IMPACT
# Center Front End             335720
# Left Front Bumper            255776
# Center Back End              247875
# Right Front Bumper           227326
# Right Front Quarter Panel    150904
# Left Front Quarter Panel     147379
# Left Rear Quarter Panel      119325
# Left Side Doors              108780
# Left Rear Bumper             108171
# Right Side Doors              92287
# Right Rear Quarter Panel      86303
# Right Rear Bumper             73405
# No Damage                     44047
# Other                         33754
# Roof                           4186
# Trailer                        3466
# Undercarriage                  1350
# Overturned                     1244
# Demolished                     1091
# Name: count, dtype: int64

# %%
# checking value counts of DRIVER_LICENSE_STATUS
df.DRIVER_LICENSE_STATUS.value_counts()
# Out:
# DRIVER_LICENSE_STATUS
# Licensed      1546893
# Unlicensed      27674
# Permit          11830
# Name: count, dtype: int64

# %%
# checking value counts of DRIVER_SEX
df.DRIVER_SEX.value_counts()
# Out:
# DRIVER_SEX
# M    1220441
# F     426570
# U       7109
# Name: count, dtype: int64

# %%
#bar chat for PRE_CRASH
df.PRE_CRASH.value_counts().plot(kind='bar')
plt.title('situation before crash')
plt.show()

# %%
# pie chart of public property damages
df.PUBLIC_PROPERTY_DAMAGE.value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('public property damaged')
plt.axis('equal')
plt.show()

# %%
#checking value counts of point of impact
df.STATE_REGISTRATION.value_counts()
# Out:
# STATE_REGISTRATION
# NY    2923340
# NJ     210381
# PA      74535
# FL      40331
# CT      38324
#        ...
# MP          1
# AS          1
# T           1
# UA          1
# LR          1
# Name: count, Length: 82, dtype: int64

# %%
#adding CRASH_DATE and CRASH_TIME VALUES in a datetime column concating them with +''+
df['datetime'] = pd.to_datetime(df['CRASH_DATE'] + ' ' + df['CRASH_TIME'])

# %%
df['datetime']
# Out:
# 0         2012-09-07 09:03:00
# 1         2019-09-23 08:15:00
# 2         2015-10-02 17:18:00
# 3         2015-10-04 20:34:00
# 4         2013-04-25 21:15:00
#                   ...
# 3704401   2021-10-11 11:00:00
# 3704402   2021-10-11 07:15:00
# 3704403   2021-10-11 00:15:00
# 3704404   2021-10-11 22:10:00
# 3704405   2021-10-08 23:30:00
# Name: datetime, Length: 3704406, dtype: datetime64[ns]

# %%
# horizantal bar graph for Travel direction
df.TRAVEL_DIRECTION.value_counts().plot(kind='barh')
plt.title('Travel direction before crash')
plt.show()

# %%
#df['year'] = df['datetime'].dt.year
#df['area'] = df['DRIVER_LICENSE_JURISDICTION'].str.split(', ').str[-1]

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64', ])
corr_matrix = numeric_columns.corr()

# Visualize the correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(corr_matrix, cmap='coolwarm')
plt.show()
